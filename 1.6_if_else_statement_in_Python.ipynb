# %% [markdown]
# <a href="https://colab.research.google.com/github/varasrisiri/Machine-Learning-Course_Part-1/blob/main/6_if_else_statement_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #simple if else statement

# %%
a = 30
b = 50

if (a>b):
  print("a is greatest number")
else:
  print("b is greatest number")
# Out:
# b is greatest number

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number"))

if (a>b):
  print("First number is the greatest number")
else:
  print("Second number is the greatest number")
# Out:
# Enter the first number: 21
# Enter the second number3
# First number is the greatest number

# %% [markdown]
# #if elif else statement

# %%
a = 30
b = 50
c = 23

if (b<a>c):
  print('a is the greatest number')
elif (a<b>c):
  print('b is the greatest number')
else:
  print("c is the greatest number")
# Out:
# b is the greatest number

# %% [markdown]
# #nesed if statement

# %%
a = 20
b = 40
c = 60

if(a>b):
  if(a>c):
    print('a is the greatest number')
  else:
    print('c is the greatest number')
else:
  if(b>c):
    print('b is the greatest number')
  else:
    print('c is the greatest number')
# Out:
# c is the greatest number
