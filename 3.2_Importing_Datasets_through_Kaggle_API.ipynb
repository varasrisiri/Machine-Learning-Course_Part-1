# %% [markdown]
# <a href="https://colab.research.google.com/github/varasrisiri/Machine-Learning-Course_Part-1/blob/main/3.2_Importing_Datasets_through_Kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API - Application Programming Interface

# %%
# installing the kaggle library

# %%
! pip install kaggle

# %% [markdown]
# #Upload your Kaggle.json file

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# #Import the Earthquake Dataset

# %%
#API to fetch the dataset from kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# LANL-Earthquake-Prediction.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# drive  kaggle.json  LANL-Earthquake-Prediction.zip  sample_data

# %%
import zipfile

with zipfile.ZipFile("LANL-Earthquake-Prediction.zip", "r") as zip_ref:
    zip_ref.extractall("LANL_Earthquake")

# %%
# !ls LANL_Earthquake
# Out:
# sample_submission.csv  test  train.csv
