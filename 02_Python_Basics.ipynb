# %% [markdown]
# <a href="https://colab.research.google.com/github/varasrisiri/Machine-Learning-Course_Part-1/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Programming Languages used for Machine Learning:
# 1. Python
# 2. R

# %% [markdown]
# #print function

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print("Machine Learning" + " Projects")
# Out:
# Machine Learning Projects

# %%
print(8)
# Out:
# 8

# %%
print(8+3)
# Out:
# 11

# %% [markdown]
# #Basic Data types:
# 1. int
# 2. float
# 3. str

# %%
type(8)
# Out:
# int

# %%
type(5.2)
# Out:
# float

# %%
type("english")
# Out:
# str

# %% [markdown]
# #Constants and Variables

# %%
super_hero = "Iron Man"
print(super_hero)
# Out:
# Iron Man

# %%
marvel_super_hero = "Captain America"
print(marvel_super_hero)
# Out:
# Captain America

# %%
hero1,hero2,hero3 = "Iron Man", "Captian America", "Bat Man"
print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron Man
# Captian America
# Bat Man

# %%
x = y = z = 23
print(x)
print(y)
print(z)
# Out:
# 23
# 23
# 23

# %% [markdown]
# #input function

# %%
number_1 = int(input("Enter the first number: "))
number_2 = int(input("Enter the second number: "))

sum = number_1 + number_2
print(sum)
# Out:
# Enter the first number: 21
# Enter the second number: 43
# 64

# %%
#changing the data type in python
num = 5
float(num)
print(float(num))
# Out:
# 5.0
