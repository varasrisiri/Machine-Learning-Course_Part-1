# %% [markdown]
# <a href="https://colab.research.google.com/github/varasrisiri/Machine-Learning-Course_Part-1/blob/main/3.1_Where_to_Collect_Data_for_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Collection Sites:
# 1. Kaggle
# 2. UCI Machine Learning Repository
# 3. Google Dataset Search

# %%
import pandas as pd

# %%
# loading a dataset to a pandas dataframe
dataset = pd.read_csv('/content/housing.csv.csv')

print(dataset)
# Out:
#     0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
dataset.head()
# Out:
#   0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0   0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1   0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2   0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3   0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4   0.02985   0.00   2.180  0  0.4580  6.4300  58...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame
